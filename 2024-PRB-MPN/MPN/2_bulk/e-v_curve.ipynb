# %%
import numpy as np
import matplotlib.pyplot as plt
import os

work_dir = os.getcwd()
setting = work_dir.split('/')[-2].split('-')[1:]

title_map = {
    'gamma':r"\gamma",
    'gammanl':r"\gamma_{nl}",
    'tanhxi':r"\tilde{\xi}",
    'tanhxi_nl':r"\tilde{\xi}_{nl}",
    'tanhp':r"\tilde{p}",
    'tanhq':r"\tilde{q}",
    'tanh_pnl':r"\tilde{p_{nl}}",
    'tanh_qnl':r"\tilde{q_{nl}}",
    'tanhp_nl':r"\tilde{p}_{nl}",
    'tanhq_nl':r"\tilde{q}_{nl}",
}

title = r"{$"
for each in setting:
    title += title_map[each] + r", "
title = title[:-2] + r"$}"

print(title)
# Out:
# {$\tilde{\xi}, \tilde{\xi}_{nl}, \tilde{p}, \tilde{p}_{nl}$}

# %% [markdown]
# fcc, hcp, bcc, sc Al的能量体积曲线
#
# 体材料性质：
#
# | structure | $V_0$ ($\rm{\AA}^3$) | $E_0$ ($\rm{eV}$) | $B$ ($\rm{GPa}$)|
# | --------- | ------------------- | --------- | ------- |
# | fcc | $17.240848$ | $-56.441868$ | $63.161174$ |
# | hcp | $17.359730$ | $0.021669$ | $61.245806$ |
# | bcc | $17.772601$ | $0.090848$ | $53.554315$ |
# | sc  | $21.896047$ | $0.158683$ | $36.073598$ |
#
# 0_al/abacus/bcc4/log:WARNING: XTOL TEST SATISFIED

# %%
# files = ['./0_al/abacus/Al.curve','/home/dell/1_work/1_ABACUS_OFDFT/1_of_test/7_wt_accuracy_test-2022-08-10/fullfft-2022-08-31/0_al/abacus/Al.curve', "/home/dell/1_work/TKK_abacus/1_EFTKK_Al/1_get_ev/Al.curve"]
# files = ['./0_al/abacus/Al.curve', "/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/0_al/0_e-v_curve/Al.curve"]
files = ['./0_al/abacus/Al.curve', './0_al-feg/abacus/Al.curve', "/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/0_al/0_e-v_curve/Al.curve", "/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/4_wt-pbe/0_data_set/0_al/0_e-v_curve/Al.curve",
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/0_al/0_e-v_curve/Al.curve',         
         "/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/6_tf+-pbe//0_data_set/0_al/0_e-v_curve/Al.curve", "/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/7_lkt-pbe//0_data_set/0_al/0_e-v_curve/Al.curve"]
# labels = ['ML', 'WT', 'KS']
# labels = ['ML', 'KS']
labels = ['ML', 'MPN', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# labels = ['ML', 'ML-FEG', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# colors = ['navy', '#ff5b00', 'r']
colors = ['navy', 'navy', '#ff5b00', 'seagreen', 'm', 'orange']
# unconv = np.hstack([np.array([10]), 11+np.array([10])])
unconv = np.array([])
plt.figure(dpi=200)
# for i in [1,2,3]:
for i in [1,2]:
# for i in [1,2,3,4]:
# for i in [1,2,3,4,5]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='fcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='hcp ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='bcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# plt.legend(frameon=False,fontsize=9, ncol=2)
plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)', fontsize=14)
plt.ylabel('Energy (eV)', fontsize=14)
plt.title("Al", fontsize=14)
# plt.title(title)
plt.show()
# plt.savefig('al_curve.png', dpi=350)

# %%
# files = ['./3_mg/abacus/Mg.curve','/home/dell/1_work/1_ABACUS_OFDFT/1_of_test/7_wt_accuracy_test-2022-08-10/fullfft-2022-08-31/3_mg/abacus/Mg.curve']
# files = ['./3_mg/abacus/Mg.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/2_mg/0_e-v_curve/Mg.curve']
files = ['./3_mg/abacus/Mg.curve','./3_mg-feg/abacus/Mg.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/2_mg/0_e-v_curve/Mg.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/4_wt-pbe/0_data_set/2_mg/0_e-v_curve/Mg.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/2_mg/0_e-v_curve/Mg.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/6_tf+-pbe/0_data_set/2_mg/0_e-v_curve/Mg.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/7_lkt-pbe/0_data_set/2_mg/0_e-v_curve/Mg.curve']
# labels = ['ML', 'WT']
# labels = ['ML', 'KS']
labels = ['ML', 'MPN', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# labels = ['ML', 'ML-FEG', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# colors = ['navy', '#ff5b00', 'r']
colors = ['navy', 'navy', '#ff5b00', 'seagreen', 'm', 'orange']
# unconv = np.hstack([np.array([10]), 11+np.array([10])])
unconv = np.array([])
plt.figure(dpi=200)
# for i in [1,2,3]:
for i in [1,2]:
# for i in [1,2,3,4]:
# for i in [1,2,3,4,5]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='hcp ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='fcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='bcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# plt.ylim(-24.7, -23.8)
# plt.legend(frameon=False,fontsize=9, ncol=2)
plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)', fontsize=14)
plt.ylabel('Energy (eV)', fontsize=14)
plt.title("Mg", fontsize=14)
# plt.title(title)
plt.show()

# %%
# files = ['./2_li/abacus/Li.curve','/home/dell/1_work/1_ABACUS_OFDFT/1_of_test/7_wt_accuracy_test-2022-08-10/fullfft-2022-08-31/2_li/abacus/Li.curve', '/home/dell/1_work/TKK_abacus/2_Li/2_bulk_properties/4_ks/Li.curve']
# files = ['./2_li/abacus/Li.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/1_li/0_e-v_curve/Li.curve']
files = ['./2_li/abacus/Li.curve','./2_li-feg/abacus/Li.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/1_li/0_e-v_curve/Li.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/4_wt-pbe/0_data_set/1_li/0_e-v_curve/Li.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/1_li/0_e-v_curve/Li.curve'
        #  ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/1_li/0_e-v_curve/Li.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/6_tf+-pbe/0_data_set/1_li/0_e-v_curve/Li.curve'
         ,'/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/7_lkt-pbe/0_data_set/1_li/0_e-v_curve/Li.curve']
# labels = ['ML', 'WT', 'KS']
# labels = ['ML', 'KS']
labels = ['ML', 'MPN', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# labels = ['ML', 'ML-FEG', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# colors = ['navy', '#ff5b00', 'r']
colors = ['navy', 'navy', '#ff5b00', 'seagreen', 'm', 'orange']
# unconv = np.hstack([np.array([10]), 11+np.array([10])])
unconv = np.array([])
plt.figure(dpi=200)
# for i in [1,2,3]:
for i in [1,2]:
# for i in [1,2,3,4]:
# for i in [1,2,3,4,5]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='bcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='fcc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='diamond ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# plt.legend(frameon=False,fontsize=9, ncol=2)
plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)', fontsize=14)
plt.ylabel('Energy (eV)', fontsize=14)
plt.title("Li", fontsize=14)
# plt.title(title)
plt.show()

# %%
files = ['./4_ga-feg/0_e-v_curve/Ga.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/8_Ga/0_e-v_curve/Ga.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/4_wt-pbe/0_data_set/8_Ga/0_e-v_curve/Ga.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/8_Ga/0_e-v_curve/Ga.curve',
        #  '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/8_Ga/0_e-v_curve/Ga.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/6_tf+-pbe/0_data_set/8_Ga/0_e-v_curve/Ga.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/7_lkt-pbe/0_data_set/8_Ga/0_e-v_curve/Ga.curve']
# labels = ['ML', 'WT', 'KS']
# labels = ['ML', 'KS']
labels = ['ML-FEG', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# colors = ['navy', '#ff5b00', 'r']
colors = ['r', 'k', 'seagreen', 'm', 'orange', '#ff5b00']
# unconv = np.hstack([np.array([10]), 11+np.array([10])])
unconv = np.array([])
plt.figure(dpi=200)
# for i in [1,2,3]:
for i in [0,1,2,3,5]:
# for i in [1,2,3,4,5]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='alpha-Ga ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='fcc ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='diamond ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(frameon=False,fontsize=9, ncol=2)
# plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)')
plt.ylabel('Energy (eV)')
plt.title(title)
plt.show()

# %%
files = ['./5_in-feg/0_e-v_curve/In.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/9_In/0_e-v_curve/In.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/4_wt-pbe/0_data_set/9_In/0_e-v_curve/In.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/9_In/0_e-v_curve/In.curve',
        #  '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/8_wgc-pbe-profess/0_data_set/9_In/0_e-v_curve/In.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/6_tf+-pbe/0_data_set/9_In/0_e-v_curve/In.curve',
         '/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/7_lkt-pbe/0_data_set/9_In/0_e-v_curve/In.curve']
# labels = ['ML', 'WT', 'KS']
# labels = ['ML', 'KS']
labels = ['ML-FEG', 'KS', 'WT', 'WGC', 'TF+', 'LKT']
# colors = ['navy', '#ff5b00', 'r']
colors = ['r', 'k', 'seagreen', 'm', 'orange', '#ff5b00']
# unconv = np.hstack([np.array([10]), 11+np.array([10])])
unconv = np.array([])
plt.figure(dpi=200)
# for i in [1,2,3]:
for i in [0,1,2,3,5]:
# for i in [1,2,3,4,5]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='In ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='fcc ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='diamond ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(frameon=False,fontsize=9, ncol=2)
# plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)')
plt.ylabel('Energy (eV)')
plt.title(title)
plt.show()

# %%
# files = ['./3_mg/abacus/Mg.curve','/home/dell/1_work/1_ABACUS_OFDFT/1_of_test/7_wt_accuracy_test-2022-08-10/fullfft-2022-08-31/3_mg/abacus/Mg.curve']
# beta_files = ['./4_mg-al/0_beta_Al3Mg/0_e-v_curve/MgAl.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/4_mg-al/0_beta_Al3Mg/0_e-v_curve/MgAl.curve',
#                 "/home/dell/1_work/7_ABACUS_ML_OF/1_test/1_train/2_ks_pbe/1_all_long_2022-12-30/1_gpq_gnl/3_bulk_properties/4_mg-al_wt/0_beta_Al3Mg_30Ry/0_e-v_curve/MgAl.curve"]
beta_files = ['./4_mg-al/0_beta_Al3Mg/0_e-v_curve/MgAl.curve','./4_mg-al_feg/0_beta_Al3Mg/0_e-v_curve/MgAl.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/4_mg-al/0_beta_Al3Mg/0_e-v_curve/MgAl.curve']
                # "/home/dell/1_work/7_ABACUS_ML_OF/1_test/1_train/2_ks_pbe/1_all_long_2022-12-30/1_gpq_gnl/3_bulk_properties/4_mg-al_wt/0_beta_Al3Mg/0_e-v_curve/MgAl.curve"]
# l12_files = ['./4_mg-al/1_L12_Mg3Al/0_e-v_curve/MgAl.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/4_mg-al/1_L12_Mg3Al/0_e-v_curve/MgAl.curve',
#                 "/home/dell/1_work/7_ABACUS_ML_OF/1_test/1_train/2_ks_pbe/1_all_long_2022-12-30/1_gpq_gnl/3_bulk_properties/4_mg-al_wt/1_L12_Mg3Al/0_e-v_curve/MgAl.curve"]
l12_files = ['./4_mg-al/1_L12_Mg3Al/0_e-v_curve/MgAl.curve','./4_mg-al_feg/1_L12_Mg3Al/0_e-v_curve/MgAl.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/4_mg-al/1_L12_Mg3Al/0_e-v_curve/MgAl.curve']
# labels = ['ML', 'WT']
# labels = ['ML', 'KS']
labels = ['ML', 'ML-FEG', 'KS']
# colors = ['navy', '#ff5b00', 'r']
colors = ['navy', 'seagreen', '#ff5b00']
unconv = np.array([])
plt.figure(dpi=200)
for i in [0,1,2]:
    file = beta_files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    if i != 1:
        plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='beta Al3Mg ({0})'.format(labels[i]),markerfacecolor='w')
    else:
        plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',markersize=10,label='beta Al3Mg ({0})'.format(labels[i]),markerfacecolor='w')

    file = l12_files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    if i != 1:
        plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-.', marker='o',label='L12 Mg3Al ({0})'.format(labels[i]),markerfacecolor='w')
    else:
        plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-.', marker='o',markersize=10,label='L12 Mg3Al ({0})'.format(labels[i]),markerfacecolor='w')

    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# plt.ylim(-24.7, -23.8)
plt.legend(frameon=False,fontsize=9, ncol=3)
# plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)')
plt.ylabel('Energy (eV)')
plt.title(title)
plt.show()

# %%
# files = ['./1_si/abacus/Si.curve','/home/dell/1_work/1_ABACUS_OFDFT/1_of_test/7_wt_accuracy_test-2022-08-10/fullfft-2022-08-31/1_si/abacus/Si.curve']
# files = ['./1_si/abacus/Si.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/3_si/0_e-v_curve/Si.curve']
files = ['./1_si/abacus/Si.curve','./1_si_feg/abacus/Si.curve','/home/dell/1_work/7_ABACUS_ML_OF/1_test/0_generate_data/2_ks-pbe/0_data_set/3_si/0_e-v_curve/Si.curve']
# labels = ['ML', 'WT']
# labels = ['ML', 'KS']
labels = ['ML', 'ML-FEG', 'KS']
# colors = ['navy', '#ff5b00', 'r']
colors = ['navy', 'seagreen', '#ff5b00']
unconv = np.array([])
plt.figure(dpi=200)
for i in [0,2]:
    file = files[i]
    curve = np.loadtxt(file, skiprows=2).T
    # if i == 0: ground = curve[1][5]
    # elif i == 1: curve[1,:] += ground - curve[1][5]
    # elif i == 2: curve[1,22:33] /= 2
    plt.plot(curve[0][:11], curve[1][:11],c=colors[i], linestyle='-', marker='d',label='CD ({0})'.format(labels[i]),markerfacecolor='w')
    plt.plot(curve[0][11:22], curve[1][11:22],c=colors[i], linestyle='-.', marker='o', label='beta-tin ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][22:33], curve[1][22:33],c=colors[i], linestyle='--', marker='v', label='sc ({0})'.format(labels[i]),markerfacecolor='w')
    # plt.plot(curve[0][33:44], curve[1][33:44],c=colors[i], linestyle=':', marker='s', label='diamond ({0})'.format(labels[i]),markerfacecolor='w')
    if i == 0:
        for each in unconv:
            plt.plot(curve[0][each], curve[1][each], marker='x', color='red')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(frameon=False,fontsize=9, ncol=2)
# plt.legend(frameon=False,fontsize=12, ncol=2)
plt.tight_layout()
plt.xlabel(r'Volume ($\rm{\AA}^3$)')
plt.ylabel('Energy (eV)')
plt.title(title)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_17122/2534001276.py in <module>
#      11 for i in [0,2]:
#      12     file = files[i]
# ---> 13     curve = np.loadtxt(file, skiprows=2).T
#      14     # if i == 0: ground = curve[1][5]
#      15     # elif i == 1: curve[1,:] += ground - curve[1][5]
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ...
